# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
from data_degradation_detector import univariate as uv, multivariate as mv
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Import data

# %%
df = pd.read_csv("bad_wine.csv")
df
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              8.8             0.610         0.30             2.8      0.088
# 1              7.6             0.420         0.25             3.9      0.104
# 2              7.8             0.560         0.19             1.8      0.104
# 3              5.6             0.660         0.00             2.5      0.066
# 4              8.6             0.635         0.68             1.8      0.403
# ..             ...               ...          ...             ...        ...
# 542           10.6             0.500         0.45             2.6      0.119
# 543           10.1             0.450         0.23             1.9      0.082
# 544           12.6             0.410         0.54             2.8      0.103
# 545           10.6             1.020         0.43             2.9      0.076
# 546            9.3             0.360         0.39             1.5      0.080
#
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
df = df.drop(columns=["Id"], axis=1)

# %%
print(f"Going from {len(df)} uncleaned columns")
df = df.drop_duplicates()
df = df.dropna()
print(f"to {len(df)} cleaned columns")
# Out:
# Going from 547 uncleaned columns
# to 516 cleaned columns

# %%
X = df.drop(columns=["quality"], axis=1)
y = df["quality"]

# %%
uv.plot_distribution_descriptors_all_columns(X)

# %%
mv.correlation_matrix(df)
